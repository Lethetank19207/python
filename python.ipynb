# %%
hall = 11.25
liv = 20.0
kit = 18.0 
bed = 10.75
bath = 9.50
areas = [hall, liv, kit, bed, bath]
print(areas)
# Out:
# [11.25, 20.0, 18.0, 10.75, 9.5]

# %%
print(areas)
# Out:
# [11.25, 20.0, 18.0, 10.75, 9.5]

# %%
print(areas)
# Out:
# [11.25, 'kitchen', 18.0, 20.0, 'bedroom', 10.75, 9.5]

# %%
house = [["hallway", hall],
        ["kitchen", kit],
        ["livingroom", liv],
        ["bedroom", bed],
        ["bathroom", bath]]
print(house)
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['livingroom', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]

# %%
print(type(house))
# Out:
# <class 'list'>
